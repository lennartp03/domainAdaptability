# %%
import cv2
import kornia as K
import kornia.feature as KF
import matplotlib.pyplot as plt
import numpy as np
import torch
import tqdm
import time
from kornia_moons.feature import *
from kornia_moons.viz import *

device = torch.device("cpu")

# %%
feature = KF.KeyNetAffNetHardNet(100, True).eval().to(device)
output_extension = ".keynet"

durations = []

# Process the file
with open("image_list_hpatches_sequences.txt", 'r') as f:
    lines = [line.strip() for line in f.readlines()]

for path in lines:

    starttime = time.time()
    print(1)
    image = K.io.load_image(path, K.io.ImageLoadType.RGB32, device=device)[None, ...]

    print(2)
    with torch.inference_mode():
        keypoints, scores, descriptors = feature(K.color.rgb_to_grayscale(image))
    
    total = round((time.time() - starttime), 2)
    durations.append(total)

    

    with open(path + output_extension, 'wb') as output_file:
        np.savez(
            output_file,
            keypoints=keypoints,
            scores=scores,
            descriptors=descriptors
            )
        
    print(f"Processed {path} in {total} seconds")
# Out:
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/5.ppm in 493.28 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/2.ppm in 538.91 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/4.ppm in 1607.48 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/1.ppm in 431.17 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/3.ppm in 473.93 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_vitro/6.ppm in 475.13 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/5.ppm in 1999.97 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/2.ppm in 1107.5 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/4.ppm in 1126.09 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/1.ppm in 1095.15 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/3.ppm in 1013.21 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_apprentices/6.ppm in 1052.31 seconds
# 1
# 2
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/5.ppm in 10.21 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/2.ppm in 10.95 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/4.ppm in 10.9 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/1.ppm in 11.59 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/3.ppm in 10.22 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/i_miniature/6.ppm in 9.94 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/5.ppm in 403.84 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/2.ppm in 418.09 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/4.ppm in 387.41 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/1.ppm in 418.92 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/3.ppm in 388.33 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_churchill/6.ppm in 407.28 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_soldiers/5.ppm in 901.52 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_soldiers/2.ppm in 557.17 seconds
# 1
# 2
# Processed hpatches_sequences/hpatches-sequences-release/v_soldiers/4.ppm in 478.67 seconds
# 1
# 2
